# %% [markdown]
# <a href="https://colab.research.google.com/github/Christydataprog/Customers/blob/main/Customer_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/Customers.csv")
df.sample(3)
# Out:
#        CustomerKey Prefix FirstName LastName          Unnamed: 4 Unnamed: 5  \
# 10485        21691    MR.   BRANDON   MARTIN  MR. BRANDON MARTIN     MARTIN
# 6623         17749   MRS.      LEAH       WU        MRS. LEAH WU         WU
# 15213        26495   MRS.   ALLISON    BAKER  MRS. ALLISON BAKER      BAKER
#
#       Unnamed: 6   BirthDate  Unnamed: 8 MaritalStatus Gender  \
# 10485        NaN    9/2/1966         NaN             S      M
# 6623         NaN  19/09/1959         NaN             M      F
# 15213        NaN  16/12/1948         NaN             S      F
#
#                     EmailAddress AnnualIncome  TotalChildren   EducationLevel  \
# 10485  brandon35@learnsector.com     $60,000               0  Graduate Degree
# 6623       leah5@learnsector.com     $10,000               1      High School
# 15213  allison39@learnsector.com     $40,000               2      High School
#
#            Occupation HomeOwner  Unnamed: 17  Unnamed: 18 BirthDate.1
# ...

# %%
df
# Out:
#        CustomerKey Prefix  FirstName LastName              Unnamed: 4  \
# 0            11000    MR.        JON     YANG            MR. JON YANG
# 1            11001    MR.     EUGENE    HUANG        MR. EUGENE HUANG
# 2            11002    MR.      RUBEN   TORRES        MR. RUBEN TORRES
# 3            11003    MS.    CHRISTY      ZHU         MS. CHRISTY ZHU
# 4            11004   MRS.  ELIZABETH  JOHNSON  MRS. ELIZABETH JOHNSON
# ...            ...    ...        ...      ...                     ...
# 18143        29479    MR.      TOMMY     TANG          MR. TOMMY TANG
# 18144        29480   MRS.       NINA     RAJI          MRS. NINA RAJI
# 18145        29481    MR.       IVAN     SURI           MR. IVAN SURI
# 18146        29482    MR.    CLAYTON    ZHANG       MR. CLAYTON ZHANG
# 18147        29483    MR.      JÉSUS  NAVARRO       MR. JÉSUS NAVARRO
#
#       Unnamed: 5 Unnamed: 6   BirthDate  Unnamed: 8 MaritalStatus Gender  \
# ...

# %%
#Deleted empty and repeated value columns
x = ['Prefix', 'Unnamed: 5','Unnamed: 6', 'Unnamed: 17', 'Unnamed: 18', 'BirthDate.1', 'Unnamed: 8']
df.drop(x, axis = 1, inplace = True)
df.head(3)
# Out:
#    CustomerKey FirstName LastName        Unnamed: 4   BirthDate MaritalStatus  \
# 0        11000       JON     YANG      MR. JON YANG    4/8/1966             M
# 1        11001    EUGENE    HUANG  MR. EUGENE HUANG  14/05/1965             S
# 2        11002     RUBEN   TORRES  MR. RUBEN TORRES   8/12/1965             M
#
#   Gender              EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0      M     jon24@learnsector.com     $90,000               2      Bachelors
# 1      M  eugene10@learnsector.com     $60,000               3      Bachelors
# 2      M   ruben35@learnsector.com     $60,000               3      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y

# %%
#Renaming Unnamed Column to Full Name
df.rename(columns={"Unnamed: 4" : "Full Name"}, inplace = True)
df.head(3)
# Out:
#    CustomerKey FirstName LastName         Full Name   BirthDate MaritalStatus  \
# 0        11000       JON     YANG      MR. JON YANG    4/8/1966             M
# 1        11001    EUGENE    HUANG  MR. EUGENE HUANG  14/05/1965             S
# 2        11002     RUBEN   TORRES  MR. RUBEN TORRES   8/12/1965             M
#
#   Gender              EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0      M     jon24@learnsector.com     $90,000               2      Bachelors
# 1      M  eugene10@learnsector.com     $60,000               3      Bachelors
# 2      M   ruben35@learnsector.com     $60,000               3      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# 1  Professional         N
# 2  Professional         Y

# %%
df.MaritalStatus = df.MaritalStatus.replace("M", "Married")
df.MaritalStatus = df.MaritalStatus.replace("S", "Single")
df.Gender = df.Gender.replace("M", "Male")
df.Gender = df.Gender.replace("F", "Female")
df.HomeOwner = df.HomeOwner.replace("Y", "Yes")
df.HomeOwner = df.HomeOwner.replace("N", "No")
df.sample(3)
# Out:
#        CustomerKey FirstName   LastName              Full Name   BirthDate  \
# 16686        27997     LYDIA   MALHOTRA    MRS. LYDIA MALHOTRA  25/09/1937
# 6578         17703    PAMELA  FERNANDEZ  MRS. PAMELA FERNANDEZ  18/02/1966
# 11297        22516  ADRIENNE     ORTEGA   MRS. ADRIENNE ORTEGA   5/12/1979
#
#       MaritalStatus  Gender                EmailAddress AnnualIncome  \
# 16686        Single  Female      lydia4@learnsector.com     $50,000
# 6578        Married  Female    pamela19@learnsector.com     $10,000
# 11297        Single  Female  adrienne17@learnsector.com     $30,000
#
#        TotalChildren   EducationLevel  Occupation HomeOwner
# 16686              3  Graduate Degree  Management        No
# 6578               1  Graduate Degree      Manual       Yes
# 11297              3  Partial College    Clerical        No

# %%
df.isnull().sum()
# Out:
# CustomerKey         0
# FirstName           0
# LastName            0
# Full Name           0
# BirthDate           0
# MaritalStatus       0
# Gender            130
# EmailAddress        0
# AnnualIncome        0
# TotalChildren       0
# EducationLevel      0
# Occupation          0
# HomeOwner           0
# dtype: int64

# %%
# Using the mode which is the "Male" to fill up the NA values
df.fillna(df.dtypes.replace({'object' : 'Male'}), inplace = True)
df.isnull().sum()
# Out:
# CustomerKey       0
# FirstName         0
# LastName          0
# Full Name         0
# BirthDate         0
# MaritalStatus     0
# Gender            0
# EmailAddress      0
# AnnualIncome      0
# TotalChildren     0
# EducationLevel    0
# Occupation        0
# HomeOwner         0
# dtype: int64

# %% [markdown]
# **Count and Bar chart for Marital status**

# %%
df.MaritalStatus.value_counts().reset_index()
# Out:
#      index  MaritalStatus
# 0  Married           9817
# 1   Single           8331

# %%
df.MaritalStatus.value_counts().plot(kind = 'bar', color = ["Blue","Red"])
plt.title("Marital Status")
plt.xlabel("Status")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# **Visualizing customer's gender using pie chart**

# %%
df.Gender.value_counts().plot(kind = 'pie')
plt.title("Gender")
# Out:
# Text(0.5, 1.0, 'Gender')

# %% [markdown]
# **Convert 'AnnualIncome' to numerical format before visualizing it using Histogram**

# %%
df.AnnualIncome
# Out:
# 0        $90,000
# 1        $60,000
# 2        $60,000
# 3        $70,000
# 4        $80,000
#            ...
# 18143    $30,000
# 18144    $30,000
# 18145    $30,000
# 18146    $30,000
# 18147    $30,000
# Name: AnnualIncome, Length: 18148, dtype: object

# %%
df.AnnualIncome = df.AnnualIncome.str.strip("$")
df.AnnualIncome
# Out:
# 0        90,000
# 1        60,000
# 2        60,000
# 3        70,000
# 4        80,000
#           ...
# 18143    30,000
# 18144    30,000
# 18145    30,000
# 18146    30,000
# 18147    30,000
# Name: AnnualIncome, Length: 18148, dtype: object

# %%
df.AnnualIncome.str.replace(",","")
# Out:
# 0        90000
# 1        60000
# 2        60000
# 3        70000
# 4        80000
#           ...
# 18143    30000
# 18144    30000
# 18145    30000
# 18146    30000
# 18147    30000
# Name: AnnualIncome, Length: 18148, dtype: object

# %%
df.AnnualIncome = df.AnnualIncome.str.replace(",","")
df.AnnualIncome
# Out:
# 0        90000
# 1        60000
# 2        60000
# 3        70000
# 4        80000
#           ...
# 18143    30000
# 18144    30000
# 18145    30000
# 18146    30000
# 18147    30000
# Name: AnnualIncome, Length: 18148, dtype: object

# %%
df.AnnualIncome.astype(int)
# Out:
# 0        90000
# 1        60000
# 2        60000
# 3        70000
# 4        80000
#          ...
# 18143    30000
# 18144    30000
# 18145    30000
# 18146    30000
# 18147    30000
# Name: AnnualIncome, Length: 18148, dtype: int64

# %%
df.AnnualIncome = df.AnnualIncome.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   FirstName       18148 non-null  object
#  2   LastName        18148 non-null  object
#  3   Full Name       18148 non-null  object
#  4   BirthDate       18148 non-null  object
#  5   MaritalStatus   18148 non-null  object
#  6   Gender          18148 non-null  object
#  7   EmailAddress    18148 non-null  object
#  8   AnnualIncome    18148 non-null  int64
#  9   TotalChildren   18148 non-null  int64
#  10  EducationLevel  18148 non-null  object
#  11  Occupation      18148 non-null  object
#  12  HomeOwner       18148 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 1.8+ MB

# %%
df.AnnualIncome.value_counts()
# Out:
# 60000     3072
# 40000     2688
# 70000     2313
# 30000     2236
# 20000     1745
# 80000     1325
# 10000     1135
# 90000      830
# 50000      661
# 100000     559
# 130000     501
# 110000     459
# 120000     324
# 170000     109
# 150000     100
# 160000      91
# Name: AnnualIncome, dtype: int64

# %%
df.AnnualIncome.value_counts().plot(kind = 'hist', color = ["green"])
plt.title("Annual Income Distribution")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Create a column for average number of Total Children for each Education Level**
#
# ---

# %%
df.describe()
# Out:
#         CustomerKey   AnnualIncome  TotalChildren
# count  18148.000000   18148.000000   18148.000000
# mean   20247.470465   57269.120564       1.843619
# std     5336.245656   32236.535573       1.613203
# min    11000.000000   10000.000000       0.000000
# 25%    15626.750000   30000.000000       0.000000
# 50%    20252.500000   60000.000000       2.000000
# 75%    24868.250000   70000.000000       3.000000
# max    29483.000000  170000.000000       5.000000

# %%
df.TotalChildren.mean()
# Out:
# 1.8436191315847477

# %%
df['Children Average'] = df.TotalChildren.mean()
df.sample()
# Out:
#       CustomerKey FirstName LastName           Full Name  BirthDate  \
# 9137        20318    AMANDA   TURNER  MRS. AMANDA TURNER  11/3/1971
#
#      MaritalStatus  Gender              EmailAddress  AnnualIncome  \
# 9137       Married  Female  amanda48@learnsector.com         60000
#
#       TotalChildren   EducationLevel      Occupation HomeOwner  \
# 9137              1  Graduate Degree  Skilled Manual       Yes
#
#       Children Average
# 9137          1.843619

# %%
df.groupby(['Children Average', "EducationLevel"]).size()
# Out:
# Children Average  EducationLevel
# 1.843619          Bachelors              5261
#                   Graduate Degree        3125
#                   High School            3241
#                   Partial College        4966
#                   Partial High School    1555
# dtype: int64

# %%
df.groupby(['Children Average', "EducationLevel"]).size().reset_index()
# Out:
#    Children Average       EducationLevel     0
# 0          1.843619            Bachelors  5261
# 1          1.843619      Graduate Degree  3125
# 2          1.843619          High School  3241
# 3          1.843619      Partial College  4966
# 4          1.843619  Partial High School  1555

# %%
sns.countplot(x = "Children Average", hue = "EducationLevel" , data = df)
plt.title("Education Level/Children Average Distribution")
# Out:
# Text(0.5, 1.0, 'Education Level/Children Average Distribution')

# %%
df['AnnualIncome Average'] = df.AnnualIncome.mean()
df.sample()
# Out:
#       CustomerKey FirstName LastName       Full Name   BirthDate  \
# 2210        13253     CARLY      XIE  MRS. CARLY XIE  20/05/1958
#
#      MaritalStatus  Gender            EmailAddress  AnnualIncome  \
# 2210       Married  Female  carly2@learnsector.com        130000
#
#       TotalChildren   EducationLevel    Occupation HomeOwner  \
# 2210              2  Partial College  Professional       Yes
#
#       Children Average  AnnualIncome Average
# 2210          1.843619          57269.120564

# %%
df.groupby(['AnnualIncome Average', "Occupation"]).size()
# Out:
# AnnualIncome Average  Occupation
# 57269.120564          Clerical          2859
#                       Management        3011
#                       Manual            2353
#                       Professional      5424
#                       Skilled Manual    4501
# dtype: int64

# %%
df.groupby(['AnnualIncome Average', "Occupation"]).size().reset_index()
# Out:
#    AnnualIncome Average      Occupation     0
# 0          57269.120564        Clerical  2859
# 1          57269.120564      Management  3011
# 2          57269.120564          Manual  2353
# 3          57269.120564    Professional  5424
# 4          57269.120564  Skilled Manual  4501

# %% [markdown]
# **Use a bar chart to compare the average AnnualIncome across different Occupation categories.**

# %%
sns.countplot(x = "AnnualIncome Average" , hue = "Occupation", data = df)
# Out:
# <Axes: xlabel='AnnualIncome Average', ylabel='count'>

# %% [markdown]
# **Visualize the count of customers in each Occupation category using a pie chart.**

# %%
df.Occupation.value_counts().plot(kind='pie', ylabel='Occupation')
# Out:
# <Axes: ylabel='Occupation'>

# %% [markdown]
# **Generate a histogram to explore the age distribution of customers**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerKey           18148 non-null  int64
#  1   FirstName             18148 non-null  object
#  2   LastName              18148 non-null  object
#  3   Full Name             18148 non-null  object
#  4   BirthDate             18148 non-null  object
#  5   MaritalStatus         18148 non-null  object
#  6   Gender                18148 non-null  object
#  7   EmailAddress          18148 non-null  object
#  8   AnnualIncome          18148 non-null  int64
#  9   TotalChildren         18148 non-null  int64
#  10  EducationLevel        18148 non-null  object
#  11  Occupation            18148 non-null  object
#  12  HomeOwner             18148 non-null  object
#  13  Children Average      18148 non-null  float64
#  14  AnnualIncome Average  18148 non-null  float64
# ...

# %%
pd.to_datetime(df.BirthDate, format = '%d/%m/%Y')
# Out:
# 0       1966-08-04
# 1       1965-05-14
# 2       1965-12-08
# 3       1968-02-15
# 4       1968-08-08
#            ...
# 18143   1958-04-07
# 18144   1960-10-11
# 18145   1960-05-01
# 18146   1959-05-03
# 18147   1959-08-12
# Name: BirthDate, Length: 18148, dtype: datetime64[ns]

# %%
df.BirthDate = pd.to_datetime(df.BirthDate, format = '%d/%m/%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerKey           18148 non-null  int64
#  1   FirstName             18148 non-null  object
#  2   LastName              18148 non-null  object
#  3   Full Name             18148 non-null  object
#  4   BirthDate             18148 non-null  datetime64[ns]
#  5   MaritalStatus         18148 non-null  object
#  6   Gender                18148 non-null  object
#  7   EmailAddress          18148 non-null  object
#  8   AnnualIncome          18148 non-null  int64
#  9   TotalChildren         18148 non-null  int64
#  10  EducationLevel        18148 non-null  object
#  11  Occupation            18148 non-null  object
#  12  HomeOwner             18148 non-null  object
#  13  Children Average      18148 non-null  float64
# ...

# %%
def age():
  current_year = 2024
  date = ("BirthDate")
  age = current_year - date
  return age

# %% [markdown]
# **Create a bar chart that shows the number of homeowners vs. non-homeowners**

# %%
df.HomeOwner.value_counts().plot(kind='bar')
plt.title("Home Owner/Non-Home Owner Distribution")
plt.ylabel("Counts")
plt.xlabel("Status")
# Out:
# Text(0.5, 0, 'Status')

# %% [markdown]
# **Use a column chart to display the total number of customers by EducationLevel**

# %%
df.EducationLevel.value_counts().reset_index()
# Out:
#                  index  EducationLevel
# 0            Bachelors            5261
# 1      Partial College            4966
# 2          High School            3241
# 3      Graduate Degree            3125
# 4  Partial High School            1555

# %%
df.EducationLevel.value_counts().plot(kind = "pie")
plt.title("Academic Distribution")
plt.xlabel("Status")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# **Visualize the distribution of TotalChildren using a histogram**

# %%
df.TotalChildren.value_counts().reset_index()
# Out:
#    index  TotalChildren
# 0      0           5080
# 1      2           3703
# 2      1           3552
# 3      4           2259
# 4      3           2153
# 5      5           1401

# %%
df.TotalChildren.value_counts().plot(kind = 'hist', color = ["green"])
plt.title("Total Children Distribution")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.countplot(x = "TotalChildren" , data = df).plot(kind = "hist")
# Out:
# []

# %% [markdown]
# **Create a pie chart showing the proportion of different MaritalStatus categories within a specific Occupation**

# %%
df.groupby(['MaritalStatus', "Occupation"]).size().reset_index()
# Out:
#   MaritalStatus      Occupation     0
# 0       Married        Clerical  1407
# 1       Married      Management  1888
# 2       Married          Manual   791
# 3       Married    Professional  3062
# 4       Married  Skilled Manual  2669
# 5        Single        Clerical  1452
# 6        Single      Management  1123
# 7        Single          Manual  1562
# 8        Single    Professional  2362
# 9        Single  Skilled Manual  1832

# %%
df.groupby(['MaritalStatus', "Occupation"]).size().plot(kind = "pie")
# Out:
# <Axes: >

# %% [markdown]
# **Plot a bar chart comparing the count of male vs. female customers in each EducationLevel**

# %%
df.groupby(['Gender', "EducationLevel"]).size().reset_index()
# Out:
#    Gender       EducationLevel     0
# 0  Female            Bachelors  2564
# 1  Female      Graduate Degree  1567
# 2  Female          High School  1555
# 3  Female      Partial College  2465
# 4  Female  Partial High School   741
# 5    Male            Bachelors  2697
# 6    Male      Graduate Degree  1558
# 7    Male          High School  1686
# 8    Male      Partial College  2501
# 9    Male  Partial High School   814

# %%
df.groupby(['Gender', "EducationLevel"]).size().plot(kind = "bar")
plt.title("Gender Education Level Distribution")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# **Use a line chart to depict the average number of TotalChildren across different income ranges**

# %%
df.groupby(['Children Average', "AnnualIncome"]).size().reset_index()
# Out:
#     Children Average  AnnualIncome     0
# 0           1.843619         10000  1135
# 1           1.843619         20000  1745
# 2           1.843619         30000  2236
# 3           1.843619         40000  2688
# 4           1.843619         50000   661
# 5           1.843619         60000  3072
# 6           1.843619         70000  2313
# 7           1.843619         80000  1325
# 8           1.843619         90000   830
# 9           1.843619        100000   559
# 10          1.843619        110000   459
# 11          1.843619        120000   324
# 12          1.843619        130000   501
# 13          1.843619        150000   100
# 14          1.843619        160000    91
# 15          1.843619        170000   109

# %%
df.groupby(['Children Average', "AnnualIncome"]).size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Children Average,AnnualIncome'>

# %% [markdown]
# **Generate a column chart that illustrates the count of customers by HomeOwner status for each MaritalStatus**

# %%
df.groupby(['HomeOwner', "MaritalStatus"]).size().reset_index()
# Out:
#   HomeOwner MaritalStatus     0
# 0        No       Married  1816
# 1        No        Single  4072
# 2       Yes       Married  8001
# 3       Yes        Single  4259

# %%
df.groupby(['HomeOwner', "MaritalStatus"]).size().plot(kind = "line")
# Out:
# <Axes: xlabel='HomeOwner,MaritalStatus'>

# %% [markdown]
# **Visualize the distribution of customers' birth months using a bar chart (Extract month from BirthDate)**

# %%
df.BirthDate.dt.month.reset_index()
# Out:
#        index  BirthDate
# 0          0          8
# 1          1          5
# 2          2         12
# 3          3          2
# 4          4          8
# ...      ...        ...
# 18143  18143          4
# 18144  18144         10
# 18145  18145          5
# 18146  18146          5
# 18147  18147          8
#
# [18148 rows x 2 columns]

# %%
df['BirthMonth'] = df.BirthDate.dt.month
df.sample()
# Out:
#       CustomerKey FirstName LastName             Full Name  BirthDate  \
# 6421        17543  MEREDITH   MARTIN  MRS. MEREDITH MARTIN 1962-08-15
#
#      MaritalStatus  Gender                EmailAddress  AnnualIncome  \
# 6421        Single  Female  meredith22@learnsector.com         70000
#
#       TotalChildren EducationLevel    Occupation HomeOwner  Children Average  \
# 6421              1      Bachelors  Professional        No          1.843619
#
#       AnnualIncome Average  BirthMonth
# 6421          57269.120564           8

# %%
df.BirthMonth.value_counts().reset_index()
# Out:
#     index  BirthMonth
# 0      11        1709
# 1      10        1672
# 2       3        1649
# 3       8        1635
# 4       6        1618
# 5       4        1617
# 6       5        1607
# 7       2        1578
# 8       9        1565
# 9       7        1502
# 10     12        1165
# 11      1         831

# %%
df.BirthMonth.value_counts().plot(kind = "bar")
plt.title("Birth Month Count")
plt.xlabel("Birth Month")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# **Create a pie chart to represent the proportion of customers by Occupation within a specific income range.**

# %%
df.groupby(['Occupation', 'AnnualIncome']).size().reset_index()
# Out:
#         Occupation  AnnualIncome     0
# 0         Clerical         10000    84
# 1         Clerical         20000   510
# 2         Clerical         30000  1388
# 3         Clerical         40000   877
# 4       Management         40000   126
# 5       Management         50000   128
# 6       Management         60000   420
# 7       Management         70000   420
# 8       Management         80000   359
# 9       Management         90000   187
# 10      Management        100000   338
# 11      Management        110000   337
# 12      Management        120000   161
# 13      Management        130000   331
# 14      Management        150000    59
# 15      Management        160000    64
# 16      Management        170000    81
# 17          Manual         10000  1015
# 18          Manual         20000  1153
# 19          Manual         30000   185
# 20    Professional         30000    78
# 21    Professional         40000   488
# 22    Professional         50000    14
# ...

# %%
df.groupby(['Occupation', 'AnnualIncome']).size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation,AnnualIncome'>

# %% [markdown]
# **Use a bar chart to show the frequency of each EducationLevel category**

# %%
df.EducationLevel.value_counts().reset_index()
# Out:
#                  index  EducationLevel
# 0            Bachelors            5261
# 1      Partial College            4966
# 2          High School            3241
# 3      Graduate Degree            3125
# 4  Partial High School            1555

# %%
df.EducationLevel.value_counts().plot(kind = 'bar')
plt.title("Education Level count")
plt.xlabel("Education")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')
